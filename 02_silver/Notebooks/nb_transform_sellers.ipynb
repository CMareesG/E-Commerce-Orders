# %%
# %sql
SELECT * FROM ecommerce_orders.`01_bronze`.sellers;

# %%
# %sql
SELECT COUNT(*) AS null_count
FROM ecommerce_orders.`01_bronze`.sellers
WHERE seller_id IS NULL

# %%
# %sql
SELECT COUNT(*) AS null_count
FROM ecommerce_orders.`01_bronze`.sellers
WHERE seller_zip_code_prefix IS NULL

# %%
# %sql
SELECT COUNT(*) AS null_count
FROM ecommerce_orders.`01_bronze`.sellers
WHERE seller_city
 IS NULL

# %%
# %sql
SELECT COUNT(*) AS null_count
FROM ecommerce_orders.`01_bronze`.sellers
WHERE seller_state IS NULL

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.`02_silver`.sellers AS
SELECT seller_id,
CASE WHEN seller_zip_code_prefix IS NULL OR seller_zip_code_prefix = '' THEN 'Unknown' ELSE seller_zip_code_prefix END AS seller_zip_code_prefix,
CASE WHEN seller_city IS NULL OR seller_city = '' THEN 'Unknown' ELSE seller_city END AS seller_city,
CASE WHEN seller_state IS NULL OR seller_state = '' THEN 'Unknown' ELSE seller_state END AS seller_state
FROM ecommerce_orders.`01_bronze`.sellers

# %%
# %sql
SELECT * FROM ecommerce_orders.`02_silver`.sellers;
