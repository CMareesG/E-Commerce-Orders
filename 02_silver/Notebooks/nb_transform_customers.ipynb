# %%
# %sql
# SELECT * FROM ecommerce_orders.`01_bronze`.customers;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce_orders.02_silver;

# %%
# %sql
# SELECT COUNT(customer_id) FROM ecommerce_orders.`01_bronze`.customers;

# %%
# %sql
# SELECT COUNT(DISTINCT customer_id) FROM ecommerce_orders.`01_bronze`.customers;

# %%
# %sql
# SELECT COUNT(*) AS null_customer_id_count
# FROM ecommerce_orders.`01_bronze`.customers
# WHERE customer_state IS NULL

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.`02_silver`.customers AS
SELECT 
  customer_id,
  customer_unique_id,
  coalesce(customer_zip_code_prefix,'0') AS customer_zip_code_prefix,
  coalesce(customer_city,'Unknown') AS customer_city,
  coalesce(customer_state,'Unknown') AS customer_state
FROM ecommerce_orders.`01_bronze`.customers;

# %%
# %sql
# SELECT * FROM ecommerce_orders.`02_silver`.customers;
