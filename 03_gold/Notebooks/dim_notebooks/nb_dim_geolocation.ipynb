# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.03_gold.dim_geolocation AS
SELECT DISTINCT
    geolocation_zip_code_prefix,
    geolocation_city,
    geolocation_state
FROM ecommerce_orders.02_silver.geolocation;

# %%
# %sql
# SELECT * FROM ecommerce_orders.03_gold.dim_geolocation;
