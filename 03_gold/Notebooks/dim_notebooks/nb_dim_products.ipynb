# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.03_gold.dim_products AS
SELECT DISTINCT
    product_id,
    product_category_name
FROM ecommerce_orders.02_silver.products;

# %%
# %sql
SELECT * FROM ecommerce_orders.`03_gold`.dim_products
