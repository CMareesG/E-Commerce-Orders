# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.03_gold.dim_customer AS
SELECT DISTINCT
    customer_id,
    customer_unique_id,
    customer_zip_code_prefix
    FROM ecommerce_orders.02_silver.customers

# %%
# %sql
SELECT * FROM ecommerce_orders.03_gold.dim_customer;
