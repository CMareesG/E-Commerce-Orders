# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.03_gold.dim_sellers AS
SELECT DISTINCT
    seller_id
FROM ecommerce_orders.02_silver.sellers;

# %%
# %sql
SELECT * FROM ecommerce_orders.03_gold.dim_sellers;
