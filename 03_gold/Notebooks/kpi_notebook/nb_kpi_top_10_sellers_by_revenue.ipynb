# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.03_gold.kpi_top10_sellers_by_revenue AS
SELECT seller_id,SUM(revenue) AS revenue
FROM ecommerce_orders.`03_gold`.curated_ecommerce
GROUP BY seller_id
ORDER BY revenue DESC
LIMIT 10;
