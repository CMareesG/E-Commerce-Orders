# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.03_gold.kpi_payment_method_dist AS
SELECT payment_types, COUNT(*) as count
FROM ecommerce_orders.`03_gold`.curated_ecommerce
GROUP BY payment_types;

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders.03_gold.kpi_payment_method_dist AS
SELECT payment_types,COUNT(*) AS count
FROM ecommerce_orders.`03_gold`.curated_ecommerce
WHERE payment_types IS NOT NULL
GROUP BY payment_types;

# %%
# %sql
SELECT * FROM ecommerce_orders.03_gold.kpi_payment_method_dist;
