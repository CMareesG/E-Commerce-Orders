# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce_orders.01_bronze;

# %%
df = spark.read.format("csv")\
    .option("header","true")\
        .load("s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/olist_customers_dataset.csv")

df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("ecommerce_orders.01_bronze.customers")

# %%
df.show()

# %%
# %sql
SELECT * FROM `ecommerce_orders`.`01_bronze`.customers;

# %%
df = spark.read.format("csv")\
    .option("header","true")\
        .load("s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/olist_geolocation_dataset.csv")

df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("ecommerce_orders.01_bronze.geolocation")

# %%
# %sql
SELECT * FROM `ecommerce_orders`.`01_bronze`.geolocation;

# %%
df = spark.read.format("csv")\
    .option("header","true")\
        .load("s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/olist_order_items_dataset.csv")

df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("ecommerce_orders.01_bronze.order_items")

# %%
# %sql

SELECT * FROM `ecommerce_orders`.`01_bronze`.order_items;

# %%
df = spark.read.format("csv")\
    .option("header","true")\
        .load("s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/olist_order_payments_dataset.csv")

df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("ecommerce_orders.01_bronze.order_payments")

# %%
# %sql
SELECT DISTINCT payment_type FROM `ecommerce_orders`.`01_bronze`.order_payments;

# %%
# %sql
SELECT * FROM `ecommerce_orders`.`01_bronze`.order_payments;

# %%
# %pip install openpyxl

# %%
# %restart_python

# %%
import pandas as pd
import io

s3_path = "s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/olist_order_reviews_dataset.csv.xlsx"

file_content = spark.read.format("binaryFile").load(s3_path).collect()[0]["content"]

pandas_df = pd.read_excel(io.BytesIO(file_content))

for col in pandas_df.columns:
    if pandas_df[col].dtype == 'object':
        pandas_df[col] = pandas_df[col].astype(str)

df = spark.createDataFrame(pandas_df)

df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_orders.01_bronze.order_reviews")

# %%
# %sql
# DROP TABLE ecommerce_orders.`01_bronze`.order_reviews;

# %%
# %sql
SELECT * FROM `ecommerce_orders`.`01_bronze`.order_reviews;

# %%
df = spark.read.format("csv")\
    .option("header","true")\
        .load("s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/olist_orders_dataset.csv")

df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("ecommerce_orders.01_bronze.orders")

# %%
# %sql
SELECT * FROM `ecommerce_orders`.`01_bronze`.orders;

# %%
df = spark.read.format("csv")\
    .option("header","true")\
        .load("s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/olist_products_dataset.csv")

df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("ecommerce_orders.01_bronze.products")

# %%
# %sql
SELECT * FROM ecommerce_orders.`01_bronze`.products;

# %%
df = spark.read.format("csv")\
    .option("header","true")\
        .load("s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/olist_sellers_dataset.csv")

df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("ecommerce_orders.01_bronze.sellers")

# %%
# %sql
SELECT * FROM ecommerce_orders.`01_bronze`.sellers;

# %%
df = spark.read.format("csv")\
    .option("header","true")\
        .load("s3://ecommerce-order-s3-bucket-781856668143-ap-southeast-1-an/OlistDataset/product_category_name_translation.csv")

df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("ecommerce_orders.01_bronze.product_category_name_translation")

# %%
# %sql
SELECT * FROM `ecommerce_orders`.`01_bronze`.product_category_name_translation;
